# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent.parent))

import shutil

from rdflib import Graph

import kgsaf_jdex.utils.conventions.paths as pc
from kgsaf_jdex.utils.conversion import OWLConverter, TSVConverter

home_path = Path.cwd().parent.parent.resolve()
data_path = home_path / "kgsaf_data" / "datasets"

# %% [markdown]
# # UNZIP Compressed Datasets

# %%
home_path = Path.cwd().parent.parent.resolve()
data_path = home_path / "kgsaf_data" / "datasets"

for d_type in [data_path / "base", data_path / "materialize"]:
    print(f"Unpacking Datasets in {d_type}")
    (d_type / "unpack").mkdir(exist_ok=True, parents=True)
    for elem in d_type.iterdir():
        if elem.is_file():
            print(f"\tUnpacking Dataset {elem.name}")
            target_folder = d_type / "unpack" / elem.stem

            if target_folder.exists():
                shutil.rmtree(target_folder)

            shutil.unpack_archive(str(elem), str(target_folder))
# Out:
# Unpacking Datasets in /home/navis/dev/kg-saf/kgsaf_data/datasets/base
# 	Unpacking Dataset DBPEDIA25-50K-C-BASE.zip
# 	Unpacking Dataset ARCO25-5-BASE.zip
# 	Unpacking Dataset WHOW25-5-BASE.zip
# 	Unpacking Dataset YAGO3-10-C-BASE.zip
# 	Unpacking Dataset DBPEDIA25-100K-C-BASE.zip
# 	Unpacking Dataset YAGO4-20-C-BASE.zip
# 	Unpacking Dataset ARCO25-20-BASE.zip
# 	Unpacking Dataset ARCO25-10-BASE.zip
# 	Unpacking Dataset YAGO3-39K-C-BASE.zip
# 	Unpacking Dataset ATRAVEL-BASE.zip
# Unpacking Datasets in /home/navis/dev/kg-saf/kgsaf_data/datasets/materialize
# 	Unpacking Dataset WHOW25-5-MATERIALIZE.zip
# 	Unpacking Dataset DBPEDIA25-50K-C-MATERIALIZE.zip
# 	Unpacking Dataset ATRAVEL-MATERIALIZE.zip
# 	Unpacking Dataset YAGO3-10-C-MATERIALIZE.zip
# 	Unpacking Dataset ARCO25-20-MATERIALIZE.zip
# 	Unpacking Dataset ARCO25-5-MATERIALIZE.zip
# 	Unpacking Dataset YAGO3-39K-C-MATERIALIZE.zip
# 	Unpacking Dataset ARCO25-10-MATERIALIZE.zip
# 	Unpacking Dataset YAGO4-20-C-MATERIALIZE.zip
# 	Unpacking Dataset DBPEDIA25-100K-C-MATERIALIZE.zip

# %% [markdown]
# # UNZIP Compressed Ontologies (Schema)

# %%
home_path = Path.cwd().parent.parent.resolve()
data_path = home_path / "kgsaf_data" / "ontologies"


print(f"Unpacking Ontologies in {data_path}")
(data_path / "unpack").mkdir(exist_ok=True, parents=True)
target_folder = data_path / "unpack" 

for elem in data_path.iterdir():
    if elem.is_file():
            print(f"\tUnpacking Ontology {elem.name}")
            
            if (target_folder / elem.stem).exists():
                shutil.rmtree(target_folder)

            shutil.unpack_archive(str(elem), str(target_folder))
# Out:
# Unpacking Ontologies in /home/navis/dev/kg-saf/kgsaf_data/ontologies
# 	Unpacking Ontology YAGO3.zip
# 	Unpacking Ontology DBPEDIA-2025.zip
# 	Unpacking Ontology ARCO-2025.zip
# 	Unpacking Ontology WHOW.zip
# 	Unpacking Ontology APULIATRAVEL.zip
# 	Unpacking Ontology YAGO4.zip

# %% [markdown]
# # Object Property Assertion Re-Merge

# %%
home_path = Path.cwd().parent.parent.resolve()
data_path = home_path / "kgsaf_data" / "datasets"

for d_type in [data_path / "base" / "unpack", data_path / "materialize" / "unpack"]:
    print(f"Merging Object Assertions for Datasets in {d_type}")
    for data_folder in d_type.iterdir():
        if data_folder.is_dir():
            print(f"\t Merging Dataset {data_folder.name}")
            # !cat {data_folder}/abox/splits/*.nt > {data_folder}/abox/obj_prop_assertions.nt
# Out:
# Merging Object Assertions for Datasets in /home/navis/dev/kg-saf/kgsaf_data/datasets/base/unpack
# 	 Merging Dataset ARCO25-10-BASE
# 	 Merging Dataset DBPEDIA25-100K-C-BASE
# 	 Merging Dataset YAGO3-10-C-BASE
# 	 Merging Dataset ARCO25-5-BASE
# 	 Merging Dataset DBPEDIA25-50K-C-BASE
# 	 Merging Dataset WHOW25-5-BASE
# 	 Merging Dataset ARCO25-20-BASE
# 	 Merging Dataset YAGO3-39K-C-BASE
# 	 Merging Dataset YAGO4-20-C-BASE
# 	 Merging Dataset ATRAVEL-BASE
# Merging Object Assertions for Datasets in /home/navis/dev/kg-saf/kgsaf_data/datasets/materialize/unpack
# 	 Merging Dataset ARCO25-10-MATERIALIZE
# 	 Merging Dataset ATRAVEL-MATERIALIZE
# 	 Merging Dataset DBPEDIA25-50K-C-MATERIALIZE
# 	 Merging Dataset YAGO3-39K-C-MATERIALIZE
# 	 Merging Dataset DBPEDIA25-100K-C-MATERIALIZE
# 	 Merging Dataset ARCO25-5-MATERIALIZE
# 	 Merging Dataset YAGO3-10-C-MATERIALIZE
# 	 Merging Dataset YAGO4-20-C-MATERIALIZE
# 	 Merging Dataset WHOW25-5-MATERIALIZE
# 	 Merging Dataset ARCO25-20-MATERIALIZE

# %% [markdown]
# # Full Knowledge Graph Re-Merge

# %%
robot_path = "/home/navis/robot/robot"
home_path = Path.cwd().parent.parent.resolve()
data_path = home_path / "kgsaf_data" / "datasets"

for d_type in [data_path / "base" / "unpack", data_path / "materialize" / "unpack"]:
    print(f"Merging Full KG for Datasets in {d_type}")
    for data_folder in d_type.iterdir():
        if data_folder.is_dir():
            print(f"\t Merging Dataset {data_folder.name}")
            # !{robot_path} merge \
            --input {data_folder / "ontology.owl"} \
            --input {data_folder / "abox" / "individuals.owl"} \
            --input {data_folder / "abox" / "obj_prop_assertions.nt"} \
            --input {data_folder / "abox" / "class_assertions.owl"} \
            --output {data_folder / "knowledge_graph.owl"}
# Out:
# Merging Full KG for Datasets in /home/navis/dev/kg-saf/kgsaf_data/datasets/base/unpack
# 	 Merging Dataset ARCO25-10-BASE
# 	 Merging Dataset DBPEDIA25-100K-C-BASE
# 	 Merging Dataset YAGO3-10-C-BASE
# 	 Merging Dataset ARCO25-5-BASE
# 	 Merging Dataset DBPEDIA25-50K-C-BASE
# 	 Merging Dataset WHOW25-5-BASE
# 	 Merging Dataset ARCO25-20-BASE
# 	 Merging Dataset YAGO3-39K-C-BASE
# 	 Merging Dataset YAGO4-20-C-BASE
# 	 Merging Dataset ATRAVEL-BASE
# Merging Full KG for Datasets in /home/navis/dev/kg-saf/kgsaf_data/datasets/materialize/unpack
# 	 Merging Dataset ARCO25-10-MATERIALIZE
# 	 Merging Dataset ATRAVEL-MATERIALIZE
# 	 Merging Dataset DBPEDIA25-50K-C-MATERIALIZE
# 	 Merging Dataset YAGO3-39K-C-MATERIALIZE
# 	 Merging Dataset DBPEDIA25-100K-C-MATERIALIZE
# 	 Merging Dataset ARCO25-5-MATERIALIZE
# 	 Merging Dataset YAGO3-10-C-MATERIALIZE
# 	 Merging Dataset YAGO4-20-C-MATERIALIZE
# 	 Merging Dataset WHOW25-5-MATERIALIZE
# 	 Merging Dataset ARCO25-20-MATERIALIZE

# %% [markdown]
# # NTriples to PyKEEN TSV Conversion

# %%
robot_path = "/home/navis/robot/robot"
home_path = Path.cwd().parent.parent.resolve()
data_path = home_path / "kgsaf_data" / "datasets"

for d_type in [data_path / "base" / "unpack", data_path / "materialize" / "unpack"]:
    print(f"Converting NTriples Datasets in {d_type}")
    for data_folder in d_type.iterdir():
        if data_folder.is_dir():
            print(f"\t Converting Dataset {data_folder.name}")
            processor = TSVConverter(data_folder)
            processor.convert()
            processor.serialize()
# Out:
# Converting NTriples Datasets in /home/navis/dev/kg-saf/kgsaf_data/datasets/base/unpack
# 	 Converting Dataset ARCO25-10-BASE
# 	 Converting Dataset DBPEDIA25-100K-C-BASE
# 	 Converting Dataset YAGO3-10-C-BASE
# 	 Converting Dataset ARCO25-5-BASE
# 	 Converting Dataset DBPEDIA25-50K-C-BASE
# 	 Converting Dataset WHOW25-5-BASE
# 	 Converting Dataset ARCO25-20-BASE
# 	 Converting Dataset YAGO3-39K-C-BASE
# 	 Converting Dataset YAGO4-20-C-BASE
# 	 Converting Dataset ATRAVEL-BASE
# Converting NTriples Datasets in /home/navis/dev/kg-saf/kgsaf_data/datasets/materialize/unpack
# 	 Converting Dataset ARCO25-10-MATERIALIZE
# 	 Converting Dataset ATRAVEL-MATERIALIZE
# 	 Converting Dataset DBPEDIA25-50K-C-MATERIALIZE
# 	 Converting Dataset YAGO3-39K-C-MATERIALIZE
# 	 Converting Dataset DBPEDIA25-100K-C-MATERIALIZE
# 	 Converting Dataset ARCO25-5-MATERIALIZE
# 	 Converting Dataset YAGO3-10-C-MATERIALIZE
# 	 Converting Dataset YAGO4-20-C-MATERIALIZE
# 	 Converting Dataset WHOW25-5-MATERIALIZE
# 	 Converting Dataset ARCO25-20-MATERIALIZE

# %% [markdown]
# # JSON OWL Conversion

# %%
home_path = Path.cwd().parent.parent.resolve()
data_path = home_path / "kgsaf_data" / "datasets"

for d_type in [data_path / "base" / "unpack", data_path / "materialize" / "unpack"]:
    print(f"Conversion to JSON for Datasets in {d_type}")
    for data_folder in d_type.iterdir():
        if data_folder.is_dir():
            print(f"\tProcessing Dataset {data_folder.name}")
            processor = OWLConverter(data_folder)
            processor.preprocess(verbose=False)
            processor.serialize()
# Out:
# Conversion to JSON for Datasets in /home/navis/dev/kg-saf/kgsaf_data/datasets/base/unpack
# 	Processing Dataset ARCO25-10-BASE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/base/unpack/ARCO25-10-BASE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset DBPEDIA25-100K-C-BASE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/base/unpack/DBPEDIA25-100K-C-BASE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset YAGO3-10-C-BASE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/base/unpack/YAGO3-10-C-BASE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset ARCO25-5-BASE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/base/unpack/ARCO25-5-BASE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset DBPEDIA25-50K-C-BASE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/base/unpack/DBPEDIA25-50K-C-BASE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset WHOW25-5-BASE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/base/unpack/WHOW25-5-BASE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset ARCO25-20-BASE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/base/unpack/ARCO25-20-BASE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset YAGO3-39K-C-BASE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/base/unpack/YAGO3-39K-C-BASE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset YAGO4-20-C-BASE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/base/unpack/YAGO4-20-C-BASE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset ATRAVEL-BASE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/base/unpack/ATRAVEL-BASE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# Conversion to JSON for Datasets in /home/navis/dev/kg-saf/kgsaf_data/datasets/materialize/unpack
# 	Processing Dataset ARCO25-10-MATERIALIZE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/materialize/unpack/ARCO25-10-MATERIALIZE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset ATRAVEL-MATERIALIZE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/materialize/unpack/ATRAVEL-MATERIALIZE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset DBPEDIA25-50K-C-MATERIALIZE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/materialize/unpack/DBPEDIA25-50K-C-MATERIALIZE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset YAGO3-39K-C-MATERIALIZE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/materialize/unpack/YAGO3-39K-C-MATERIALIZE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset DBPEDIA25-100K-C-MATERIALIZE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/materialize/unpack/DBPEDIA25-100K-C-MATERIALIZE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset ARCO25-5-MATERIALIZE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/materialize/unpack/ARCO25-5-MATERIALIZE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset YAGO3-10-C-MATERIALIZE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/materialize/unpack/YAGO3-10-C-MATERIALIZE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset YAGO4-20-C-MATERIALIZE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/materialize/unpack/YAGO4-20-C-MATERIALIZE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset WHOW25-5-MATERIALIZE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/materialize/unpack/WHOW25-5-MATERIALIZE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
# 	Processing Dataset ARCO25-20-MATERIALIZE
# Processing Dataset at /home/navis/dev/kg-saf/kgsaf_data/datasets/materialize/unpack/ARCO25-20-MATERIALIZE
# Processing Taxonomy
# Processing Class Assertions
# Processing Object Property Hierarchy
# Processing Object Property Domain and Range
